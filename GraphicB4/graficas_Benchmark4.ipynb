# %% [markdown]
# ## TASK 4: Benchmark of matrix multiplication

# %%
import matplotlib.pyplot as plt
import numpy as np

files = ["matrix_128.txt", "matrix_256.txt", "matrix_512.txt", "matrix_1024.txt"]
sequential_times = [17.935, 21.7619, 196.8893, 2125.768]
parallel_times = [83.0663, 17.6236, 44.74, 329.5146]

matrix_sizes = [128, 256, 512, 1024]

# %%
plt.style.use('seaborn-whitegrid')

plt.figure(figsize=(12, 8))
plt.figure().patch.set_facecolor('white')

plt.plot(index, sequential_times, marker='o', label='Sequential', color=palette(0), linestyle='-', linewidth=2, markersize=10, alpha=0.8)
plt.plot(index, parallel_times, marker='o', label='Parallel', color=palette(1), linestyle='-', linewidth=2, markersize=10, alpha=0.8)
plt.errorbar(index, sequential_times, linestyle='None', marker='o', color=palette(0), yerr=5, capsize=5, elinewidth=2, alpha=0.8)
plt.errorbar(index, parallel_times, linestyle='None', marker='o', color=palette(1), yerr=5, capsize=5, elinewidth=2, alpha=0.8)
plt.xticks(index, matrix_sizes)
plt.title('Sequential vs Parallel Matrix Multiplication Times', loc='center', fontsize=18, fontweight=0, color='black')
plt.xlabel('Matrix Size', fontsize=14)
plt.ylabel('Time (ms)', fontsize=14)
plt.legend(fontsize=12)
plt.ylim(bottom=0)
plt.tight_layout()
plt.savefig('matrix_multiplication_times.png')
plt.show()
# Out:
# C:\Users\marap\AppData\Local\Temp\ipykernel_15296\1251867761.py:1: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-whitegrid')
